# %%
from IPython.display import clear_output
import random

def display_board(board):
    print(board[7]+'|'+board[8]+'|'+board[9])
    print(board[4]+'|'+board[5]+'|'+board[6])
    print(board[1]+'|'+board[2]+'|'+board[3])

testboard = [' ']*10
display_board(testboard)

def player_input():
    marker = ' '
    
    # KEEP ASKING PLAYER 1 to choose X or O
    while marker != 'X' and marker !='O':
        marker = input('Player 1, choose X or O: ')
        
    # ASSIGN PLAYER 2, the opposite marker
    player1 = marker
    
    if player1 == 'X':
        player2 = 'O'
    else:
        player2 = 'X'
        
    return (player1, player2)

board_player1 = ['#']
board_player2 = ['#']

def make_board():
    print('HI')
    ran_num1 = random.randint(1,9)
    ran_num2 = random.randint(1,9)
    
    board_player1.append(str(ran_num1))
    board_player2.append(str(ran_num2))
    
    for i in range(1,9):
        while str(ran_num1) in board_player1:
            ran_num1 = random.randint(1,9)
        board_player1.append(str(ran_num1))
            
            
        while str(ran_num2) in board_player2:
            ran_num2 = random.randint(1,9)
        board_player2.append(str(ran_num2))
    print(board_player1)
    print(board_player2)

def playing():
    is_complete = False
    while(is_complete!=True):
        x = input('Player_1, Input number for tic tac toe : ')
        i = 0
        for item in board_player1:
            if item == x:
                print('equal')
                board_player1[i] = player_marker1
                break
            i = i+1
            
        y = input('Player_2, Input number for tic tac toe : ')
        i = 0
        for item in board_player2:
            if item == y:
                board_player2[i] = player_marker2
                break
            i = i+1
        
        print('-----Board for Player1-----')
        display_board(board_player1)
        print('-----Board for Player2-----')
        display_board(board_player2)
        


player_marker1, player_marker2 = player_input()
make_board()
playing()
# Out:
#  | |
#  | |
#  | |
# Player 1, choose X or O: O
# HI
# ['#', '1', '7', '9', '6', '4', '3', '8', '2', '5']
# ['#', '1', '3', '5', '2', '6', '7', '4', '9', '8']
# Player_1, Input number for tic tac toe : 3
# # | 3
# 0
# 1 | 3
# 1
# 7 | 3
# 2
# 9 | 3
# 3
# 6 | 3
# 4
# 4 | 3
# 5
# 3 | 3
# 6
# equal
# Player_2, Input number for tic tac toe : 5
# -----Board for Player1-----
# 8|2|5
# 6|4|O
# 1|7|9
# -----Board for Player2-----
# 4|9|8
# 2|6|7
# 1|3|X
# Player_1, Input number for tic tac toe : 1
# # | 1
# 0
# 1 | 1
# 1
# equal
# Player_2, Input number for tic tac toe : 2
# -----Board for Player1-----
# 8|2|5
# 6|4|O
# O|7|9
# -----Board for Player2-----
# 4|9|8
# X|6|7
# 1|3|X
# Player_1, Input number for tic tac toe : 6
# # | 6
# 0
# O | 6
# 1
# 7 | 6
# 2
# 9 | 6
# 3
# 6 | 6
# 4
# equal
# Player_2, Input number for tic tac toe : 4
# -----Board for Player1-----
# 8|2|5
# O|4|O
# O|7|9
# -----Board for Player2-----
# X|9|8
# X|6|7
# 1|3|X
# Player_1, Input number for tic tac toe : 3
# # | 3
# ...
